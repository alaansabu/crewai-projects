# %%
from dotenv import load_dotenv


load_dotenv()

# %%
import os
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.5-flash",
    api_key=os.getenv("GEMINI_API_KEY"),
    temperature=0.7
)
# Out:
# 'The reasoning for a "Manim AI" to generate a graph for sine leverages the strengths of both Artificial Intelligence and the Manim animation engine to provide a highly accurate, customizable, and conceptually clear visualization.\n\nHere\'s a breakdown of the reasoning:\n\n---\n\n### Reasoning for Manim AI Generating a Sine Graph\n\nThe Manim AI\'s approach to generating a sine graph is driven by the need for **precision, dynamic visualization, conceptual clarity, and automated efficiency.**\n\n**1. Core Objective: Visualizing a Fundamental Mathematical Concept**\nThe sine function ($y = \\sin(x)$) is foundational in trigonometry, physics, engineering, and many other fields. A clear, accurate, and animated visualization is crucial for understanding its properties (periodicity, amplitude, phase, roots, extrema).\n\n**2. Why Manim is the Ideal Visualization Engine:**\n\n*   **Mathematical Precision:** Manim is built to render mathematical objects with exactness. It can draw smooth curv
# ...

# %%
original_email = """
Dear Mr. Anderson,

I hope this email finds you well.

I am writing to SDS to follow up on our recent discussion and to check if there are any updates or additional information required from my side. Please let me know if there are any next steps or timelines I should be aware of.

Thank you for your time and consideration. I look forward to your response.
"""

from crewai.tools import BaseTool


class replaceJargonsTools(BaseTool):
    name: str = "Replace jargons"
    description: str = "Replace jargons with specific terms"
   
    def _run(self, email: str) -> str:
        replacements = {
            "PRX": "Project Phoenix (internal AI revamp project)",
            "TAS": "technical architecture stack",
            "DBX": "client database cluster",
            "SDS": "Smart Data Syncer",
            "SYNCBOT": "internal standup assistant bot",
            "WIP": "in progress",
            "POC": "proof of concept",
            "ping": "reach out"
        }
        suggestions = []
        email_lower = email.lower()
        for jargon, replacement in replacements.items():
            if jargon.lower() in email_lower:
                suggestions.append(f"Consider replacing '{jargon}' with '{replacement}'")

        return '\n'.join(suggestions) if suggestions else "No jargons found"
    


jt = replaceJargonsTools()
jt.run(original_email)

# %%
from crewai import Crew, Task, Agent

email_assistant = Agent(
    role="Professional Email Assistant",
    goal="Write professional emails to the team that are clean and clear",
    backstory="A skilled professional in making emails more professional",
    tools = [jt],
    verbose=True,
    llm=llm
)

original_email = """
Dear Mr. Anderson,

I hope this email finds you well.

I am writing prx sds to follow up on our recent discussion and to check if there are any updates or additional information required from my side. Please let me know if there are any next steps or timelines I should be aware of.

Thank you for your time and consideration. I look forward to your response.
"""


email_task = Task(
    description=f"""
    Take the following   rough email and rewrite it into a professional and polished version.
    Expand abbreviations:
    '''{original_email}'''
    """,
    agent=email_assistant,
    expected_output="A professionally written email"
)

crew = Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: e225a657-ed02-436a-9773-f7eb8c3b8f8f                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...
